# %%
# script to re-scale well log data
# most of the heavy lifting done with lasio (github)

# Big thanks to Ross Meyer and Kent

# %%
import lasio
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ls
# Out:
# 204-20-1_logs.las*              las_resample_and_write.ipynb
# LASxPlot.ipynb*                 plot_with_image.ipynb*
# data_explor.ipynb               xgb_wavenet_preds_204_19_6.csv

# %%
datafile="204-20-1_logs.las" # read in your datafile

l = lasio.read(datafile)
# Out:
# Header section Parameter regexp=~P was not found.

# %%
df = l.df()
df.head(8) # Lets check that it works!
# Out:
#           CALI  DENC  DENS  DTC  DTS       GR  NEUT  PEF  RDEP  RMIC  RSHAL  \
# DEPTH
# 400.0000   NaN   NaN   NaN  NaN  NaN      NaN   NaN  NaN   NaN   NaN    NaN
# 400.1524   NaN   NaN   NaN  NaN  NaN      NaN   NaN  NaN   NaN   NaN    NaN
# 400.3048   NaN   NaN   NaN  NaN  NaN      NaN   NaN  NaN   NaN   NaN    NaN
# 400.4572   NaN   NaN   NaN  NaN  NaN      NaN   NaN  NaN   NaN   NaN    NaN
# 400.6096   NaN   NaN   NaN  NaN  NaN      NaN   NaN  NaN   NaN   NaN    NaN
# 400.7620   NaN   NaN   NaN  NaN  NaN  39.1675   NaN  NaN   NaN   NaN    NaN
# 400.9144   NaN   NaN   NaN  NaN  NaN  36.6688   NaN  NaN   NaN   NaN    NaN
# 401.0668   NaN   NaN   NaN  NaN  NaN  34.0544   NaN  NaN   NaN   NaN    NaN
#
#           SP
# DEPTH
# 400.0000 NaN
# 400.1524 NaN
# 400.3048 NaN
# 400.4572 NaN
# 400.6096 NaN
# 400.7620 NaN
# 400.9144 NaN
# 401.0668 NaN

# %%
x = np.arange(400, 2500, 0.1) # top, bottom, step size

d = {}

for c in df.columns:
    d[c] = np.interp(x, df.index.values, df[c].values, left=np.nan, right=np.nan)
    
df_resample = pd.DataFrame(d, index=x)
df_resample.head(10)
# Out:
#        CALI  DENC  DENS  DTC  DTS         GR  NEUT  PEF  RDEP  RMIC  RSHAL  SP
# 400.0   NaN   NaN   NaN  NaN  NaN        NaN   NaN  NaN   NaN   NaN    NaN NaN
# 400.1   NaN   NaN   NaN  NaN  NaN        NaN   NaN  NaN   NaN   NaN    NaN NaN
# 400.2   NaN   NaN   NaN  NaN  NaN        NaN   NaN  NaN   NaN   NaN    NaN NaN
# 400.3   NaN   NaN   NaN  NaN  NaN        NaN   NaN  NaN   NaN   NaN    NaN NaN
# 400.4   NaN   NaN   NaN  NaN  NaN        NaN   NaN  NaN   NaN   NaN    NaN NaN
# 400.5   NaN   NaN   NaN  NaN  NaN        NaN   NaN  NaN   NaN   NaN    NaN NaN
# 400.6   NaN   NaN   NaN  NaN  NaN        NaN   NaN  NaN   NaN   NaN    NaN NaN
# 400.7   NaN   NaN   NaN  NaN  NaN        NaN   NaN  NaN   NaN   NaN    NaN NaN
# 400.8   NaN   NaN   NaN  NaN  NaN  38.544465   NaN  NaN   NaN   NaN    NaN NaN
# 400.9   NaN   NaN   NaN  NaN  NaN  36.904898   NaN  NaN   NaN   NaN    NaN NaN

# %%
type(df_resample)
# Out:
# pandas.core.frame.DataFrame

# %%
las = lasio.read(datafile)
# Out:
# Header section Parameter regexp=~P was not found.

# %%
las.set_data_from_df(df_resample)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-aa2e57757159> in <module>()
# ----> 1 las.set_data_from_df(df_resample)
#
# /anaconda3/envs/wells/lib/python3.6/site-packages/lasio/las.py in set_data_from_df(self, df, **kwargs)
#     637         if (not 'names' in kwargs) or (not kwargs['names']):
#     638             kwargs['names'] = [df.index.name] + [str(name) for name in df.columns.values]
# --> 639         self.set_data(df_values, **kwargs)
#     640
#     641     @property
#
# /anaconda3/envs/wells/lib/python3.6/site-packages/lasio/las.py in set_data(self, array_like, names, truncate)
#     620
#     621         for i, curve in enumerate(self.curves):
# --> 622             curve.mnemonic = names[i]
#     623             curve.data = data[:, i]
#     624
#
# ...

# %%
# The resample did not take

qq = las.df()
qq.head(10)
# Out:
#           CALI  DENC  DENS  DTC  DTS       GR  NEUT  PEF  RDEP  RMIC  RSHAL  \
# DEPTH
# 400.0000   NaN   NaN   NaN  NaN  NaN      NaN   NaN  NaN   NaN   NaN    NaN
# 400.1524   NaN   NaN   NaN  NaN  NaN      NaN   NaN  NaN   NaN   NaN    NaN
# 400.3048   NaN   NaN   NaN  NaN  NaN      NaN   NaN  NaN   NaN   NaN    NaN
# 400.4572   NaN   NaN   NaN  NaN  NaN      NaN   NaN  NaN   NaN   NaN    NaN
# 400.6096   NaN   NaN   NaN  NaN  NaN      NaN   NaN  NaN   NaN   NaN    NaN
# 400.7620   NaN   NaN   NaN  NaN  NaN  39.1675   NaN  NaN   NaN   NaN    NaN
# 400.9144   NaN   NaN   NaN  NaN  NaN  36.6688   NaN  NaN   NaN   NaN    NaN
# 401.0668   NaN   NaN   NaN  NaN  NaN  34.0544   NaN  NaN   NaN   NaN    NaN
# 401.2192   NaN   NaN   NaN  NaN  NaN  34.8124   NaN  NaN   NaN   NaN    NaN
# 401.3716   NaN   NaN   NaN  NaN  NaN  36.6110   NaN  NaN   NaN   NaN    NaN
#
#           SP
# DEPTH
# 400.0000 NaN
# 400.1524 NaN
# 400.3048 NaN
# 400.4572 NaN
# 400.6096 NaN
# 400.7620 NaN
# 400.9144 NaN
# ...
